# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.predict("https://ultralytics.com/images/bus.jpg", save=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# ...
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 22.9ms
# Speed: 11.5ms preprocess, 22.9ms inference, 33.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="my-api-key")

project = rf.workspace("wafaes-workspace").project("garbage-classification-3-uclja")

dataset = project.version(1).download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 113.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 213.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to GARBAGE-CLASSIFICATION-3-1 in yolov8:: 100%|██████████| 20933/20933 [00:00<00:00, 35078.52it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data=dataset.location + "/data.yaml",
    epochs=40,
    imgsz=640
)
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA RTX PRO 6000 Blackwell Server Edition, 97250MiB)
# ...

# %%
model.predict(
    source="/content/GARBAGE-CLASSIFICATION-3-1/test/images",
    save=True,
    stream=True
)
# Out:
# <generator object BasePredictor.stream_inference at 0x79090430b760>

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from IPython.display import Image as IPyImage
IPyImage(filename='/content/runs/detect/train/confusion_matrix.png', width=800)
IPyImage(filename='/content/runs/detect/train/results.png', width=800)
